# %% [markdown]
# <a href="https://colab.research.google.com/github/IsuruKRanasundara/AI_Projects/blob/main/CV_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installing dependency to email agent
# !pip install transformers accelerate bitsandbytes fpdf
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 15.4 MB/s eta 0:00:00
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=35c67d2c5663a3037642b2192765409235167791e6dd90687e8a8f8778cac7af
#   Stored in directory: /root/.cache/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# ...

# %%
skills = "Python, Machine Learning, SQL"
experience = "Software engineering intern working with Angular and AI systems"
job_description = "Looking for a junior AI engineer with Python and ML experience"

prompt = f"""
Create a professional resume and a cover letter.

Skills: {skills}
Experience: {experience}
Job Description: {job_description}

Generate:
1. Resume
2. Cover Letter
"""

# %%
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

outputs = model.generate(
    **inputs,
    max_new_tokens=400,
    temperature=0.7
)

result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(result)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Create a professional resume and a cover letter.
#
# Skills: Python, Machine Learning, SQL
# Experience: Software engineering intern working with Angular and AI systems
# Job Description: Looking for a junior AI engineer with Python and ML experience
#
# Generate:
# 1. Resume
# 2. Cover Letter
#
# Resume:
#
# Name: John Doe
# Address: 123 Main Street, Anytown USA
# Phone: 555-555-5555
# Email: johndoe@email.com
#
# Summary:
# Highly motivated and detail-oriented software engineering intern with experience in Angular and AI systems. Seeking a junior AI engineer position to apply Python and ML skills.
#
# Education:
# Bachelor of Science in Computer Science, XYZ University, Anytown USA
# Expected Graduation: May 20XX
#
# Experience:
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "mistralai/Mistral-7B-Instruct-v0.1"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# ...

# %%
from fpdf import FPDF

pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)

for line in result.split("\n"):
    pdf.cell(200, 10, txt=line, ln=True)

pdf.output("resume_coverletter.pdf")
# Out:
# ''

# %%
from google.colab import files

files.download("resume_coverletter.pdf")

# %%
pip install fastapi uvicorn

# %%
# %%writefile main.py
from fastapi import FastAPI

app = FastAPI()

@app.get("/hello")
async def read_root():
    return {"message": "Hello, FastAPI from Colab!"}
# Out:
# Writing main.py

# %%
pip install pyngrok

# %%
from pyngrok import ngrok
import uvicorn
import nest_asyncio

nest_asyncio.apply()

# Terminate any existing ngrok tunnels
ngrok.kill()

# Start ngrok tunnel
# Replace 'your_ngrok_auth_token' with your actual ngrok auth token if you have one,
# otherwise, ngrok might limit tunnel duration. You can get one from ngrok.com.
# ngrok.set_auth_token("your_ngrok_auth_token")

public_url = ngrok.connect(8000).public_url
print(f"Public URL: {public_url}")

# Run the FastAPI app with uvicorn in a separate thread/process to keep the notebook responsive
# For simplicity, we're using nest_asyncio to run it in the current event loop.
uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# ERROR:pyngrok.process.ngrok:t=2026-03-07T10:27:31+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-03-07T10:27:31+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ...

# %% [markdown]
# After running the previous cell, you should see a `Public URL` printed. You can access your FastAPI endpoint by navigating to `[Public URL]/hello` in your web browser or by using a tool like `curl`.
